# %%
import os
import csv
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# The packages here below are needed for visualizations, such as Matplotlib, Seaborn, and Plotly:

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib import cm
import seaborn as sns

# %%
df = pd.read_csv('\\Users\\GTX8WNS\\Desktop\\SMU\\Data Mining\\KobeCompletedos.csv')
df
print df.head()
# Out:
#          action_type combined_shot_type  type  game_event_id   game_id  \
# 0          Jump Shot          Jump Shot     1             12  20000012
# 1          Jump Shot          Jump Shot     1             35  20000012
# 2          Jump Shot          Jump Shot     1             43  20000012
# 3  Driving Dunk Shot               Dunk     3            155  20000012
# 4          Jump Shot          Jump Shot     1            244  20000012
#
#        lat  loc_x  loc_y       lon  minutes_remaining   ...         shot_type  \
# 0  34.0443   -157      0 -118.4268                 10   ...    2PT Field Goal
# 1  33.9093   -101    135 -118.3708                  7   ...    2PT Field Goal
# 2  33.8693    138    175 -118.1318                  6   ...    2PT Field Goal
# 3  34.0443      0      0 -118.2698                  6   ...    2PT Field Goal
# 4  34.0553   -145    -11 -118.4148                  9   ...    2PT Field Goal
#
#           shot_zone_area  shot_zone_basic  shot_zone_range     team_id  \
# 0           Left Side(L)        Mid-Range         8-16 ft.  1610612747
# 1   Left Side Center(LC)        Mid-Range        16-24 ft.  1610612747
# 2  Right Side Center(RC)        Mid-Range        16-24 ft.  1610612747
# 3              Center(C)  Restricted Area  Less Than 8 ft.  1610612747
# 4           Left Side(L)        Mid-Range         8-16 ft.  1610612747
#
#             team_name   game_date    matchup opponent shot_id
# 0  Los Angeles Lakers  10/31/2000  LAL @ POR      POR       2
# 1  Los Angeles Lakers  10/31/2000  LAL @ POR      POR       3
# 2  Los Angeles Lakers  10/31/2000  LAL @ POR      POR       4
# 3  Los Angeles Lakers  10/31/2000  LAL @ POR      POR       5
# 4  Los Angeles Lakers  10/31/2000  LAL @ POR      POR       6
#
# [5 rows x 26 columns]

# %%
os.getcwd()
# Out:
# 'C:\\Users\\GTX8WNS'

# %%
#DATA UNDERSTANDING : 2.Describe the meaning and type of data (scale, values, etc.) for each
#attribute in the data file.
df.columns
df.index
df.values
df.dtypes
df.describe
# Out:
# action_type            object
# combined_shot_type     object
# type                    int64
# game_event_id           int64
# game_id                 int64
# lat                   float64
# loc_x                   int64
# loc_y                   int64
# lon                   float64
# minutes_remaining       int64
# period                  int64
# playoffs                int64
# season                 object
# seconds_remaining       int64
# shot_distance           int64
# shot_made_flag          int64
# shot_type              object
# shot_zone_area         object
# shot_zone_basic        object
# shot_zone_range        object
# team_id                 int64
# team_name              object
# game_date              object
# matchup                object
# opponent               object
# shot_id                 int64
# dtype: object

# %%
df.count()
# Out:
# action_type           25696
# combined_shot_type    25696
# type                  25696
# game_event_id         25696
# game_id               25696
# lat                   25696
# loc_x                 25696
# loc_y                 25696
# lon                   25696
# minutes_remaining     25696
# period                25696
# playoffs              25696
# season                25696
# seconds_remaining     25696
# shot_distance         25696
# shot_made_flag        25696
# shot_type             25696
# shot_zone_area        25696
# shot_zone_basic       25696
# shot_zone_range       25696
# team_id               25696
# team_name             25696
# game_date             25696
# matchup               25696
# opponent              25696
# shot_id               25696
# dtype: int64

# %%
# DATA UNDERSTANDING: #3. Verify data quality: Explain any missing values, duplicate data, and outliers.
# Are those mistakes? How do you deal with these problems? Be specific.

# The following command will indicate those cells with "True" where there is a missing value
pd.isnull(df).head(3)

# There is a simple way to check the number of missing values per variable, using the function
df.isnull().sum()

# The inverse is also possible, that is counting the number of nonmissing values.
df.count()

# To remove the Ouliers for each of your dataframe column, you could get quantile and then filter
q = df["minutes_remaining"].quantile(0.99)
df[df["minutes_remaining"] < q]
# Out:
#               action_type combined_shot_type  type  game_event_id   game_id  \
# 0               Jump Shot          Jump Shot     1             12  20000012
# 1               Jump Shot          Jump Shot     1             35  20000012
# 2               Jump Shot          Jump Shot     1             43  20000012
# 3       Driving Dunk Shot               Dunk     3            155  20000012
# 4               Jump Shot          Jump Shot     1            244  20000012
# 5              Layup Shot              Layup     2            251  20000012
# 6               Jump Shot          Jump Shot     1            265  20000012
# 7       Running Jump Shot          Jump Shot     1            294  20000012
# 8               Jump Shot          Jump Shot     1            309  20000012
# 10      Running Jump Shot          Jump Shot     1             27  20000019
# 11              Jump Shot          Jump Shot     1             66  20000019
# 12              Jump Shot          Jump Shot     1             80  20000019
# 13              Jump Shot          Jump Shot     1             86  20000019
# 14              Jump Shot          Jump Shot     1            138  20000019
# 16              Jump Shot          Jump Shot     1            255  20000019
# 17              Jump Shot          Jump Shot     1            265  20000019
# 18      Running Jump Shot          Jump Shot     1            274  20000019
# 19      Running Jump Shot          Jump Shot     1            299  20000019
# 20      Running Jump Shot          Jump Shot     1            307  20000019
# 21             Layup Shot              Layup     2            332  20000019
# 22              Jump Shot          Jump Shot     1            345  20000019
# 23              Jump Shot          Jump Shot     1            369  20000019
# 24              Jump Shot          Jump Shot     1            400  20000019
# 25              Jump Shot          Jump Shot     1            429  20000019
# 26      Running Jump Shot          Jump Shot     1            488  20000019
# 27              Jump Shot          Jump Shot     1            499  20000019
# 28              Jump Shot          Jump Shot     1            184  20000047
# 29              Jump Shot          Jump Shot     1            202  20000047
# 31             Layup Shot              Layup     2            219  20000047
# 32              Jump Shot          Jump Shot     1            229  20000047
# ...                   ...                ...   ...            ...       ...
# 25665          Layup Shot              Layup     2            238  49900087
# 25666      Slam Dunk Shot               Dunk     3            245  49900087
# 25667           Jump Shot          Jump Shot     1            259  49900087
# 25668           Jump Shot          Jump Shot     1            270  49900087
# 25669          Layup Shot              Layup     2            280  49900087
# 25670           Jump Shot          Jump Shot     1            295  49900087
# 25671           Jump Shot          Jump Shot     1            368  49900087
# 25672           Jump Shot          Jump Shot     1            425  49900087
# 25673   Running Jump Shot          Jump Shot     1             15  49900088
# 25674  Driving Layup Shot              Layup     2             25  49900088
# 25675           Jump Shot          Jump Shot     1             29  49900088
# 25676           Jump Shot          Jump Shot     1             36  49900088
# 25677           Jump Shot          Jump Shot     1             81  49900088
# 25678           Jump Shot          Jump Shot     1             84  49900088
# 25679   Running Jump Shot          Jump Shot     1             98  49900088
# 25680           Jump Shot          Jump Shot     1            101  49900088
# 25681  Driving Layup Shot              Layup     2            181  49900088
# 25682          Layup Shot              Layup     2            212  49900088
# 25683           Jump Shot          Jump Shot     1            218  49900088
# 25684           Jump Shot          Jump Shot     1            228  49900088
# 25685           Jump Shot          Jump Shot     1            231  49900088
# 25686           Jump Shot          Jump Shot     1            249  49900088
# 25687           Jump Shot          Jump Shot     1            284  49900088
# 25688           Jump Shot          Jump Shot     1            308  49900088
# 25689           Jump Shot          Jump Shot     1            326  49900088
# 25691  Driving Layup Shot              Layup     2            382  49900088
# 25692           Jump Shot          Jump Shot     1            397  49900088
# 25693   Running Jump Shot          Jump Shot     1            426  49900088
# 25694           Jump Shot          Jump Shot     1            448  49900088
# 25695           Jump Shot          Jump Shot     1            471  49900088
#
#            lat  loc_x  loc_y       lon  minutes_remaining   ...    \
# 0      34.0443   -157      0 -118.4268                 10   ...
# 1      33.9093   -101    135 -118.3708                  7   ...
# 2      33.8693    138    175 -118.1318                  6   ...
# 3      34.0443      0      0 -118.2698                  6   ...
# 4      34.0553   -145    -11 -118.4148                  9   ...
# 5      34.0443      0      0 -118.2698                  8   ...
# 6      33.9363    -65    108 -118.3348                  6   ...
# 7      33.9193    -33    125 -118.3028                  3   ...
# 8      33.8063    -94    238 -118.3638                  1   ...
# 10     33.9343    -67    110 -118.3368                  7   ...
# 11     34.0403    -94      4 -118.3638                  2   ...
# 12     33.9973    -23     47 -118.2928                  1   ...
# 13     33.8523     62    192 -118.2078                  0   ...
# 14     33.8183   -117    226 -118.3868                  8   ...
# 16     33.9003      3    144 -118.2668                 10   ...
# 17     33.9173    134    127 -118.1358                  9   ...
# 18     33.9343    -16    110 -118.2858                  7   ...
# 19     33.8943   -109    150 -118.3788                  5   ...
# 20     33.9813    -46     63 -118.3158                  5   ...
# 21     34.0443      0      0 -118.2698                  2   ...
# 22     33.8483    -58    196 -118.3278                  2   ...
# 23     33.8583   -183    186 -118.4528                  0   ...
# 24     33.8713     85    173 -118.1848                  8   ...
# 25     33.9573      3     87 -118.2668                  6   ...
# 26     34.0403    121      4 -118.1488                  1   ...
# 27     34.0103    127     34 -118.1428                  0   ...
# 28     33.8603     91    184 -118.1788                  3   ...
# 29     33.7723    -27    272 -118.2968                  0   ...
# 31     34.0403      7      4 -118.2628                 10   ...
# 32     33.9113    150    133 -118.1198                  8   ...
# ...        ...    ...    ...       ...                ...   ...
# 25665  34.0263    -14     18 -118.2838                 10   ...
# 25666  34.0443      0      0 -118.2698                  9   ...
# 25667  33.9913     -8     53 -118.2778                  8   ...
# 25668  34.0193    106     25 -118.1638                  6   ...
# 25669  34.0263    -14     18 -118.2838                  5   ...
# 25670  33.8733    -81    171 -118.3508                  4   ...
# 25671  33.7943     40    250 -118.2298                  9   ...
# 25672  33.9913    171     53 -118.0988                  3   ...
# 25673  34.0283    -74     16 -118.3438                  9   ...
# 25674  34.0443      0      0 -118.2698                  8   ...
# 25675  33.9893     89     55 -118.1808                  8   ...
# 25676  34.0443    117      0 -118.1528                  7   ...
# 25677  33.8283    117    216 -118.1528                  2   ...
# 25678  33.8283   -134    216 -118.4038                  2   ...
# 25679  34.0443   -141      0 -118.4108                  0   ...
# 25680  33.9013   -113    143 -118.3828                  0   ...
# 25681  34.0283     14     16 -118.2558                  3   ...
# 25682  34.0443      0      0 -118.2698                  0   ...
# 25683  33.7833    -18    261 -118.2878                  0   ...
# 25684  33.8283      1    216 -118.2688                 10   ...
# 25685  33.9553    -96     89 -118.3658                 10   ...
# 25686  33.7943     81    250 -118.1888                  7   ...
# 25687  33.9443     40    100 -118.2298                  3   ...
# 25688  33.9833   -126     61 -118.3958                  1   ...
# 25689  33.3653    -12    679 -118.2818                  0   ...
# 25691  34.0443      0      0 -118.2698                  7   ...
# 25692  33.9963      1     48 -118.2688                  6   ...
# 25693  33.8783   -134    166 -118.4038                  3   ...
# 25694  33.7773     31    267 -118.2388                  2   ...
# 25695  33.9723      1     72 -118.2688                  0   ...
#
#             shot_type         shot_zone_area        shot_zone_basic  \
# 0      2PT Field Goal           Left Side(L)              Mid-Range
# 1      2PT Field Goal   Left Side Center(LC)              Mid-Range
# 2      2PT Field Goal  Right Side Center(RC)              Mid-Range
# 3      2PT Field Goal              Center(C)        Restricted Area
# 4      2PT Field Goal           Left Side(L)              Mid-Range
# 5      2PT Field Goal              Center(C)        Restricted Area
# 6      2PT Field Goal           Left Side(L)  In The Paint (Non-RA)
# 7      2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 8      3PT Field Goal   Left Side Center(LC)      Above the Break 3
# 10     2PT Field Goal           Left Side(L)  In The Paint (Non-RA)
# 11     2PT Field Goal           Left Side(L)              Mid-Range
# 12     2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 13     2PT Field Goal              Center(C)              Mid-Range
# 14     3PT Field Goal   Left Side Center(LC)      Above the Break 3
# 16     2PT Field Goal              Center(C)              Mid-Range
# 17     2PT Field Goal  Right Side Center(RC)              Mid-Range
# 18     2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 19     2PT Field Goal   Left Side Center(LC)              Mid-Range
# 20     2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 21     2PT Field Goal              Center(C)        Restricted Area
# 22     2PT Field Goal              Center(C)              Mid-Range
# 23     3PT Field Goal   Left Side Center(LC)      Above the Break 3
# 24     2PT Field Goal  Right Side Center(RC)              Mid-Range
# 25     2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 26     2PT Field Goal          Right Side(R)              Mid-Range
# 27     2PT Field Goal          Right Side(R)              Mid-Range
# 28     2PT Field Goal  Right Side Center(RC)              Mid-Range
# 29     3PT Field Goal              Center(C)      Above the Break 3
# 31     2PT Field Goal              Center(C)        Restricted Area
# 32     2PT Field Goal  Right Side Center(RC)              Mid-Range
# ...               ...                    ...                    ...
# 25665  2PT Field Goal              Center(C)        Restricted Area
# 25666  2PT Field Goal              Center(C)        Restricted Area
# 25667  2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 25668  2PT Field Goal          Right Side(R)              Mid-Range
# 25669  2PT Field Goal              Center(C)        Restricted Area
# 25670  2PT Field Goal   Left Side Center(LC)              Mid-Range
# 25671  3PT Field Goal              Center(C)      Above the Break 3
# 25672  2PT Field Goal          Right Side(R)              Mid-Range
# 25673  2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 25674  2PT Field Goal              Center(C)        Restricted Area
# 25675  2PT Field Goal          Right Side(R)              Mid-Range
# 25676  2PT Field Goal          Right Side(R)              Mid-Range
# 25677  3PT Field Goal  Right Side Center(RC)      Above the Break 3
# 25678  3PT Field Goal   Left Side Center(LC)      Above the Break 3
# 25679  2PT Field Goal           Left Side(L)              Mid-Range
# 25680  2PT Field Goal   Left Side Center(LC)              Mid-Range
# 25681  2PT Field Goal              Center(C)        Restricted Area
# 25682  2PT Field Goal              Center(C)        Restricted Area
# 25683  3PT Field Goal              Center(C)      Above the Break 3
# 25684  2PT Field Goal              Center(C)              Mid-Range
# 25685  2PT Field Goal           Left Side(L)              Mid-Range
# 25686  3PT Field Goal              Center(C)      Above the Break 3
# 25687  2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 25688  2PT Field Goal           Left Side(L)              Mid-Range
# 25689  3PT Field Goal         Back Court(BC)              Backcourt
# 25691  2PT Field Goal              Center(C)        Restricted Area
# 25692  2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 25693  2PT Field Goal   Left Side Center(LC)              Mid-Range
# 25694  3PT Field Goal              Center(C)      Above the Break 3
# 25695  2PT Field Goal              Center(C)  In The Paint (Non-RA)
#
#        shot_zone_range     team_id           team_name   game_date  \
# 0             8-16 ft.  1610612747  Los Angeles Lakers  10/31/2000
# 1            16-24 ft.  1610612747  Los Angeles Lakers  10/31/2000
# 2            16-24 ft.  1610612747  Los Angeles Lakers  10/31/2000
# 3      Less Than 8 ft.  1610612747  Los Angeles Lakers  10/31/2000
# 4             8-16 ft.  1610612747  Los Angeles Lakers  10/31/2000
# 5      Less Than 8 ft.  1610612747  Los Angeles Lakers  10/31/2000
# 6             8-16 ft.  1610612747  Los Angeles Lakers  10/31/2000
# 7             8-16 ft.  1610612747  Los Angeles Lakers  10/31/2000
# 8              24+ ft.  1610612747  Los Angeles Lakers  10/31/2000
# 10            8-16 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 11            8-16 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 12     Less Than 8 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 13           16-24 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 14             24+ ft.  1610612747  Los Angeles Lakers   11/1/2000
# 16            8-16 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 17           16-24 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 18            8-16 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 19           16-24 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 20     Less Than 8 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 21     Less Than 8 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 22           16-24 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 23             24+ ft.  1610612747  Los Angeles Lakers   11/1/2000
# 24           16-24 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 25            8-16 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 26            8-16 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 27            8-16 ft.  1610612747  Los Angeles Lakers   11/1/2000
# 28           16-24 ft.  1610612747  Los Angeles Lakers   11/4/2000
# 29             24+ ft.  1610612747  Los Angeles Lakers   11/4/2000
# 31     Less Than 8 ft.  1610612747  Los Angeles Lakers   11/4/2000
# 32           16-24 ft.  1610612747  Los Angeles Lakers   11/4/2000
# ...                ...         ...                 ...         ...
# 25665  Less Than 8 ft.  1610612747  Los Angeles Lakers   6/16/2000
# 25666  Less Than 8 ft.  1610612747  Los Angeles Lakers   6/16/2000
# 25667  Less Than 8 ft.  1610612747  Los Angeles Lakers   6/16/2000
# 25668         8-16 ft.  1610612747  Los Angeles Lakers   6/16/2000
# 25669  Less Than 8 ft.  1610612747  Los Angeles Lakers   6/16/2000
# 25670        16-24 ft.  1610612747  Los Angeles Lakers   6/16/2000
# 25671          24+ ft.  1610612747  Los Angeles Lakers   6/16/2000
# 25672        16-24 ft.  1610612747  Los Angeles Lakers   6/16/2000
# 25673  Less Than 8 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25674  Less Than 8 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25675         8-16 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25676         8-16 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25677          24+ ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25678          24+ ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25679         8-16 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25680        16-24 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25681  Less Than 8 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25682  Less Than 8 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25683          24+ ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25684        16-24 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25685         8-16 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25686          24+ ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25687         8-16 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25688         8-16 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25689  Back Court Shot  1610612747  Los Angeles Lakers   6/19/2000
# 25691  Less Than 8 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25692  Less Than 8 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25693        16-24 ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25694          24+ ft.  1610612747  Los Angeles Lakers   6/19/2000
# 25695  Less Than 8 ft.  1610612747  Los Angeles Lakers   6/19/2000
#
#            matchup opponent shot_id
# 0        LAL @ POR      POR       2
# 1        LAL @ POR      POR       3
# 2        LAL @ POR      POR       4
# 3        LAL @ POR      POR       5
# 4        LAL @ POR      POR       6
# 5        LAL @ POR      POR       7
# 6        LAL @ POR      POR       9
# 7        LAL @ POR      POR      10
# 8        LAL @ POR      POR      11
# 10     LAL vs. UTA      UTA      13
# 11     LAL vs. UTA      UTA      14
# 12     LAL vs. UTA      UTA      15
# 13     LAL vs. UTA      UTA      16
# 14     LAL vs. UTA      UTA      18
# 16     LAL vs. UTA      UTA      21
# 17     LAL vs. UTA      UTA      22
# 18     LAL vs. UTA      UTA      23
# 19     LAL vs. UTA      UTA      24
# 20     LAL vs. UTA      UTA      25
# 21     LAL vs. UTA      UTA      26
# 22     LAL vs. UTA      UTA      27
# 23     LAL vs. UTA      UTA      28
# 24     LAL vs. UTA      UTA      29
# 25     LAL vs. UTA      UTA      30
# 26     LAL vs. UTA      UTA      31
# 27     LAL vs. UTA      UTA      32
# 28       LAL @ VAN      VAN      39
# 29       LAL @ VAN      VAN      40
# 31       LAL @ VAN      VAN      42
# 32       LAL @ VAN      VAN      43
# ...            ...      ...     ...
# 25665    LAL @ IND      IND   30661
# 25666    LAL @ IND      IND   30662
# 25667    LAL @ IND      IND   30663
# 25668    LAL @ IND      IND   30664
# 25669    LAL @ IND      IND   30666
# 25670    LAL @ IND      IND   30667
# 25671    LAL @ IND      IND   30668
# 25672    LAL @ IND      IND   30670
# 25673  LAL vs. IND      IND   30671
# 25674  LAL vs. IND      IND   30672
# 25675  LAL vs. IND      IND   30673
# 25676  LAL vs. IND      IND   30674
# 25677  LAL vs. IND      IND   30675
# 25678  LAL vs. IND      IND   30676
# 25679  LAL vs. IND      IND   30677
# 25680  LAL vs. IND      IND   30678
# 25681  LAL vs. IND      IND   30679
# 25682  LAL vs. IND      IND   30680
# 25683  LAL vs. IND      IND   30682
# 25684  LAL vs. IND      IND   30684
# 25685  LAL vs. IND      IND   30685
# 25686  LAL vs. IND      IND   30686
# 25687  LAL vs. IND      IND   30688
# 25688  LAL vs. IND      IND   30689
# 25689  LAL vs. IND      IND   30690
# 25691  LAL vs. IND      IND   30692
# 25692  LAL vs. IND      IND   30693
# 25693  LAL vs. IND      IND   30695
# 25694  LAL vs. IND      IND   30696
# 25695  LAL vs. IND      IND   30697
#
# [24154 rows x 26 columns]

# %%
# DATA UNDERSTANDING: #4 Give simple, appropriate statistics (range, mode, mean, median, variance,
# counts, etc.) for the most important attributes and describe what they mean or if you
# found something interesting. Note: You can also use data from other sources for
# comparison. Explain the significance of the statistics run and why they are meaningful.

df.describe(include='all')
# Out:
#        action_type combined_shot_type          type  game_event_id  \
# count        25696              25696  25696.000000   25696.000000
# unique          55                  6           NaN            NaN
# top      Jump Shot          Jump Shot           NaN            NaN
# freq         15836              19710           NaN            NaN
# mean           NaN                NaN      1.321879     249.357059
# std            NaN                NaN      0.711421     149.775409
# min            NaN                NaN      1.000000       2.000000
# 25%            NaN                NaN      1.000000     111.000000
# 50%            NaN                NaN      1.000000     253.000000
# 75%            NaN                NaN      1.000000     367.000000
# max            NaN                NaN      6.000000     653.000000
#
#              game_id           lat         loc_x         loc_y           lon  \
# count   2.569600e+04  25696.000000  25696.000000  25696.000000  25696.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    2.474128e+07     33.953039      7.148700     91.260897   -118.262651
# std     7.738202e+06      0.088152    110.075279     88.151983      0.110075
# min     2.000001e+07     33.253300   -250.000000    -44.000000   -118.519800
# 25%     2.050006e+07     33.884300    -67.250000      4.000000   -118.337050
# 50%     2.090034e+07     33.970300      0.000000     74.000000   -118.269800
# 75%     2.960027e+07     34.040300     94.000000    160.000000   -118.175800
# max     4.990009e+07     34.088300    248.000000    791.000000   -118.021800
#
#         minutes_remaining      ...            shot_type  shot_zone_area  \
# count        25696.000000      ...                25696           25696
# unique                NaN      ...                    2               6
# top                   NaN      ...       2PT Field Goal       Center(C)
# freq                  NaN      ...                20284           11288
# mean             4.886714      ...                  NaN             NaN
# std              3.452517      ...                  NaN             NaN
# min              0.000000      ...                  NaN             NaN
# 25%              2.000000      ...                  NaN             NaN
# 50%              5.000000      ...                  NaN             NaN
# 75%              8.000000      ...                  NaN             NaN
# max             11.000000      ...                  NaN             NaN
#
#        shot_zone_basic  shot_zone_range       team_id           team_name  \
# count            25696            25696  2.569600e+04               25696
# unique               7                5           NaN                   1
# top          Mid-Range  Less Than 8 ft.           NaN  Los Angeles Lakers
# freq             10532             7856           NaN               25696
# mean               NaN              NaN  1.610613e+09                 NaN
# std                NaN              NaN  0.000000e+00                 NaN
# min                NaN              NaN  1.610613e+09                 NaN
# 25%                NaN              NaN  1.610613e+09                 NaN
# 50%                NaN              NaN  1.610613e+09                 NaN
# 75%                NaN              NaN  1.610613e+09                 NaN
# max                NaN              NaN  1.610613e+09                 NaN
#
#         game_date    matchup opponent       shot_id
# count       25696      25696    25696  25696.000000
# unique       1558         74       33           NaN
# top     4/13/2016  LAL @ SAS      SAS           NaN
# freq           43        853     1638           NaN
# mean          NaN        NaN      NaN  15328.757900
# std           NaN        NaN      NaN   8860.128375
# min           NaN        NaN      NaN      2.000000
# 25%           NaN        NaN      NaN   7646.750000
# 50%           NaN        NaN      NaN  15336.500000
# 75%           NaN        NaN      NaN  22976.250000
# max           NaN        NaN      NaN  30697.000000
#
# [11 rows x 26 columns]

# %%
# DATA UNDERSTANDING: #5 Visualize the most important attributes appropriately (at least 5 attributes).
#Important: Provide an interpretation for each chart. Explain for each attribute why the
#chosen visualization is appropriate.
